# %%
import pandas as pd
# Load CSV file
data = pd.read_csv('KMeansClustering.csv')

# %%
data.head()
# Out:
#   Company  Clients  Rate of Return     Sales  Years  Cluster
# 0       A      150            15.4  50400200     18        1
# 1       B      144            11.3  42100650     15        2
# 2       C      120             9.9  39440420     12        2
# 3       D      110            12.5  36500520     16        2
# 4       E      100             9.7  40650005     10        2

# %%
data.tail()
# Out:
#    Company  Clients  Rate of Return     Sales  Years  Cluster
# 17       R       49             9.8  14568990      6        3
# 18       S       75            11.7  37555000      8        2
# 19       T       46             8.7  22342600      5        3
# 20       U       79             8.9  32465890      9        2
# 21       V       90             9.4  34560000     10        2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company         22 non-null     object
#  1   Clients         22 non-null     int64
#  2   Rate of Return  22 non-null     float64
#  3   Sales           22 non-null     int64
#  4   Years           22 non-null     int64
#  5   Cluster         22 non-null     int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 1.2+ KB

# %%
data.describe()
# Out:
#           Clients  Rate of Return         Sales      Years    Cluster
# count   22.000000       22.000000  2.200000e+01  22.000000  22.000000
# mean   101.272727       11.459091  3.618874e+07  10.909091   2.000000
# std     32.250776        2.214381  1.025649e+07   3.816120   0.755929
# min     46.000000        8.600000  1.456899e+07   5.000000   1.000000
# 25%     76.000000        9.475000  2.791685e+07   8.000000   1.250000
# 50%    101.500000       11.500000  3.772790e+07  11.000000   2.000000
# 75%    128.000000       13.000000  4.488892e+07  13.750000   2.750000
# max    150.000000       15.400000  5.040020e+07  18.000000   3.000000

# %%
import pandas as pd

# Create a DataFrame from the provided data
data = pd.DataFrame({
    'Clients': [22, 101.272727, 32.250776, 46, 76, 101.5, 128, 150],
    'Rate of Return': [22, 11.459091, 2.214381, 8.6, 9.475, 11.5, 13, 15.4],
    'Sales': [22, 36188740, 10256490, 14568990, 27916850, 37727900, 44888920, 50400200],
    'Years': [22, 10.909091, 3.81612, 5, 8, 11, 13.75, 18],
    'Cluster': [22, 2, 0.755929, 1, 1.25, 2, 2.75, 3]
})

# Display the data
print(data)
# Out:
#       Clients  Rate of Return     Sales      Years    Cluster
# 0   22.000000       22.000000        22  22.000000  22.000000
# 1  101.272727       11.459091  36188740  10.909091   2.000000
# 2   32.250776        2.214381  10256490   3.816120   0.755929
# 3   46.000000        8.600000  14568990   5.000000   1.000000
# 4   76.000000        9.475000  27916850   8.000000   1.250000
# 5  101.500000       11.500000  37727900  11.000000   2.000000
# 6  128.000000       13.000000  44888920  13.750000   2.750000
# 7  150.000000       15.400000  50400200  18.000000   3.000000

# %%
# Prepare the data for clustering
from sklearn.cluster import KMeans

# Get the features for clustering
features = data[['Clients', 'Rate of Return', 'Sales', 'Years']]

# Perform K-means clustering with a specified number of clusters (e.g., 3)
n_clusters = 4
kmeans = KMeans(n_clusters=n_clusters)
kmeans.fit(features)

# Get the cluster labels
cluster_labels = kmeans.labels_

# Add the cluster labels to the DataFrame
data['KMeans Cluster'] = cluster_labels

# Display the updated DataFrame
print(data)
# Out:
#       Clients  Rate of Return     Sales      Years    Cluster  KMeans Cluster
# 0   22.000000       22.000000        22  22.000000  22.000000               3
# 1  101.272727       11.459091  36188740  10.909091   2.000000               1
# 2   32.250776        2.214381  10256490   3.816120   0.755929               0
# 3   46.000000        8.600000  14568990   5.000000   1.000000               0
# 4   76.000000        9.475000  27916850   8.000000   1.250000               1
# 5  101.500000       11.500000  37727900  11.000000   2.000000               1
# 6  128.000000       13.000000  44888920  13.750000   2.750000               2
# 7  150.000000       15.400000  50400200  18.000000   3.000000               2
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Prepare the data for clustering
from sklearn.cluster import KMeans

# Get the features for clustering
features = data[['Clients', 'Rate of Return', 'Sales', 'Years']]

# Perform K-means clustering with a specified number of clusters (e.g., 3)
n_clusters = 6
kmeans = KMeans(n_clusters=n_clusters)
kmeans.fit(features)

# Get the cluster labels
cluster_labels = kmeans.labels_

# Add the cluster labels to the DataFrame
data['KMeans Cluster'] = cluster_labels

# Display the updated DataFrame
print(data)
# Out:
#       Clients  Rate of Return     Sales      Years    Cluster  KMeans Cluster
# 0   22.000000       22.000000        22  22.000000  22.000000               1
# 1  101.272727       11.459091  36188740  10.909091   2.000000               4
# 2   32.250776        2.214381  10256490   3.816120   0.755929               3
# 3   46.000000        8.600000  14568990   5.000000   1.000000               3
# 4   76.000000        9.475000  27916850   8.000000   1.250000               0
# 5  101.500000       11.500000  37727900  11.000000   2.000000               4
# 6  128.000000       13.000000  44888920  13.750000   2.750000               5
# 7  150.000000       15.400000  50400200  18.000000   3.000000               2
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
#Analyzing the cluster centroids. Group the data by the 'KMeans Cluster' column and calculate the mean values for each cluster
cluster_means = data.groupby('KMeans Cluster').mean()

# Display the cluster means
print(cluster_means)
# cluster means provides insights into the different segments or groups present in the data. it also gives average values of these features for each cluster.
# Out:
#                    Clients  Rate of Return       Sales      Years    Cluster
# KMeans Cluster
# 0                76.000000        9.475000  27916850.0   8.000000   1.250000
# 1                22.000000       22.000000        22.0  22.000000  22.000000
# 2               150.000000       15.400000  50400200.0  18.000000   3.000000
# 3                39.125388        5.407190  12412740.0   4.408060   0.877965
# 4               101.386364       11.479546  36958320.0  10.954546   2.000000
# 5               128.000000       13.000000  44888920.0  13.750000   2.750000

# %%
# Create a dictionary mapping cluster numbers to meaningful labels
cluster_labels = {
    0: 'High Return, Low Sales',
    1: 'Medium Return, Medium Sales',
    2: 'Low Return, High Sales'
}

# Map the cluster labels to the 'KMeans Cluster' column in the DataFrame
data['Cluster Labels'] = data['KMeans Cluster'].map(cluster_labels)

# Display the updated DataFrame with meaningful cluster labels
print(data)
# Out:
#       Clients  Rate of Return     Sales      Years    Cluster  KMeans Cluster  \
# 0   22.000000       22.000000        22  22.000000  22.000000               1
# 1  101.272727       11.459091  36188740  10.909091   2.000000               4
# 2   32.250776        2.214381  10256490   3.816120   0.755929               3
# 3   46.000000        8.600000  14568990   5.000000   1.000000               3
# 4   76.000000        9.475000  27916850   8.000000   1.250000               0
# 5  101.500000       11.500000  37727900  11.000000   2.000000               4
# 6  128.000000       13.000000  44888920  13.750000   2.750000               5
# 7  150.000000       15.400000  50400200  18.000000   3.000000               2
#
#                 Cluster Labels
# 0  Medium Return, Medium Sales
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4       High Return, Low Sales
# 5                          NaN
# 6                          NaN
# ...

# %%
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score

# Get the ground truth labels
ground_truth_labels = data['Cluster']

# Calculate Adjusted Rand Index (ARI)
ari = adjusted_rand_score(ground_truth_labels, data['KMeans Cluster'])

# Calculate Normalized Mutual Information (NMI)
nmi = normalized_mutual_info_score(ground_truth_labels, data['KMeans Cluster'])

# Display the evaluation metrics
print(f"Adjusted Rand Index (ARI): {ari}")
print(f"Normalized Mutual Information (NMI): {nmi}")
# Out:
# Adjusted Rand Index (ARI): 0.65
# Normalized Mutual Information (NMI): 0.9523809523809523
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_supervised.py:64: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_supervised.py:64: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)

# %%
import matplotlib.pyplot as plt

# Group the data by the 'KMeans Cluster' column and calculate the mean values for each cluster
cluster_means = data.groupby('KMeans Cluster').mean()

# Display the cluster means
print(cluster_means)
# Out:
#                    Clients  Rate of Return       Sales      Years    Cluster
# KMeans Cluster
# 0                76.000000        9.475000  27916850.0   8.000000   1.250000
# 1                22.000000       22.000000        22.0  22.000000  22.000000
# 2               150.000000       15.400000  50400200.0  18.000000   3.000000
# 3                39.125388        5.407190  12412740.0   4.408060   0.877965
# 4               101.386364       11.479546  36958320.0  10.954546   2.000000
# 5               128.000000       13.000000  44888920.0  13.750000   2.750000
# <ipython-input-27-ece37410ce12>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   cluster_means = data.groupby('KMeans Cluster').mean()

# %%
# Create a box plot for each feature across clusters
features = ['Clients', 'Rate of Return', 'Sales', 'Years']
fig, axes = plt.subplots(nrows=1, ncols=len(features), figsize=(12, 4))

for i, feature in enumerate(features):
    axes[i].boxplot([data[data['KMeans Cluster'] == cluster][feature] for cluster in range(n_clusters)])
    axes[i].set_xticklabels(cluster_means.index)
    axes[i].set_xlabel('Cluster')
    axes[i].set_ylabel(feature)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the data as a pandas DataFrame
data = pd.DataFrame({
    'Clients': [22, 101, 76, 150, 46, 128, 101, 150, 46, 76, 128, 76, 101, 150, 46, 128, 101, 76, 150, 46, 101, 128],
    'Rate of Return': [11.45, 8.6, 9.475, 13, 11.5, 15.4, 11.5, 15.4, 8.6, 9.475, 13, 9.475, 11.45, 15.4, 8.6, 15.4, 11.45, 9.475, 13, 8.6, 11.45, 15.4],
    'Sales': [36188740, 14568990, 27916850, 50400200, 14568990, 44888920, 37727900, 50400200, 14568990, 27916850, 44888920, 27916850, 36188740, 50400200, 14568990, 44888920, 36188740, 27916850, 50400200, 14568990, 36188740, 44888920],
    'Years': [10.909091, 5, 8, 18, 5, 13.75, 11, 18, 5, 8, 13.75, 8, 10.909091, 18, 5, 13.75, 10.909091, 8, 18, 5, 10.909091, 13.75],
    'Cluster': [2, 1, 1, 3, 1, 2, 2, 3, 1, 1, 2, 1, 2, 3, 1, 2, 2, 1, 3, 1, 2, 2]
})

# Define the features you want to plot
features = ['Clients', 'Rate of Return', 'Sales', 'Years']

# Calculate the cluster means
cluster_means = data.groupby('Cluster').mean()

# Create a bar plot for each feature across clusters
fig, axes = plt.subplots(nrows=1, ncols=len(features), figsize=(12, 4))

for i, feature in enumerate(features):
    axes[i].bar(cluster_means.index, cluster_means[feature])
    axes[i].set_xlabel('Cluster')
    axes[i].set_ylabel(feature)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Group the data by the 'KMeans Cluster' column
clustered_data = data.groupby('KMeans Cluster')

# Calculate the correlation matrix for each cluster
correlation_matrices = clustered_data[features].corr()

# Iterate over each cluster
for cluster, correlation_matrix in correlation_matrices.groupby('KMeans Cluster'):
    # Create a heatmap for the correlation matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)

    # Add a title to the plot
    plt.title(f'Correlation Matrix - Cluster {cluster}')

    # Rotate the x-axis labels for better readability
    plt.xticks(rotation=45)

    # Show the plot
    plt.show()

# %%
import numpy as np
from sklearn.datasets import fetch_20newsgroups

categories = [
    "alt.atheism",
    "talk.religion.misc",
    "comp.graphics",
    "sci.space",
]

dataset = fetch_20newsgroups(
    remove=("headers", "footers", "quotes"),
    subset="all",
    categories=categories,
    shuffle=True,
    random_state=42,
)

labels = dataset.target
unique_labels, category_sizes = np.unique(labels, return_counts=True)
true_k = unique_labels.shape[0]

print(f"{len(dataset.data)} documents - {true_k} categories")
# Out:
# 3387 documents - 4 categories

# %%
from collections import defaultdict
from sklearn import metrics
from time import time

evaluations = []
evaluations_std = []


def fit_and_evaluate(km, X, name=None, n_runs=5):
    name = km.__class__.__name__ if name is None else name

    train_times = []
    scores = defaultdict(list)
    for seed in range(n_runs):
        km.set_params(random_state=seed)
        t0 = time()
        km.fit(X)
        train_times.append(time() - t0)
        scores["Homogeneity"].append(metrics.homogeneity_score(labels, km.labels_))
        scores["Completeness"].append(metrics.completeness_score(labels, km.labels_))
        scores["V-measure"].append(metrics.v_measure_score(labels, km.labels_))
        scores["Adjusted Rand-Index"].append(
            metrics.adjusted_rand_score(labels, km.labels_)
        )
        scores["Silhouette Coefficient"].append(
            metrics.silhouette_score(X, km.labels_, sample_size=2000)
        )
    train_times = np.asarray(train_times)

    print(f"clustering done in {train_times.mean():.2f} ± {train_times.std():.2f} s ")
    evaluation = {
        "estimator": name,
        "train_time": train_times.mean(),
    }
    evaluation_std = {
        "estimator": name,
        "train_time": train_times.std(),
    }
    for score_name, score_values in scores.items():
        mean_score, std_score = np.mean(score_values), np.std(score_values)
        print(f"{score_name}: {mean_score:.3f} ± {std_score:.3f}")
        evaluation[score_name] = mean_score
        evaluation_std[score_name] = std_score
    evaluations.append(evaluation)
    evaluations_std.append(evaluation_std)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    max_df=0.5,
    min_df=5,
    stop_words="english",
)
t0 = time()
X_tfidf = vectorizer.fit_transform(dataset.data)

print(f"vectorization done in {time() - t0:.3f} s")
print(f"n_samples: {X_tfidf.shape[0]}, n_features: {X_tfidf.shape[1]}")
# Out:
# vectorization done in 0.841 s
# n_samples: 3387, n_features: 7929

# %%
from sklearn.cluster import KMeans

for seed in range(5):
    kmeans = KMeans(
        n_clusters=true_k,
        max_iter=100,
        n_init=1,
        random_state=seed,
    ).fit(X_tfidf)
    cluster_ids, cluster_sizes = np.unique(kmeans.labels_, return_counts=True)
    print(f"Number of elements asigned to each cluster: {cluster_sizes}")
print()
print(
    "True number of documents in each category according to the class labels: "
    f"{category_sizes}"
)
# Out:
# Number of elements asigned to each cluster: [   1    1 3384    1]
# Number of elements asigned to each cluster: [1597  732  233  825]
# Number of elements asigned to each cluster: [2004  446  646  291]
# Number of elements asigned to each cluster: [1695  649  446  597]
# Number of elements asigned to each cluster: [ 254 2117  459  557]
#
# True number of documents in each category according to the class labels: [799 973 987 628]

# %%
kmeans = KMeans(
    n_clusters=true_k,
    max_iter=100,
    n_init=5,
)

fit_and_evaluate(kmeans, X_tfidf, name="KMeans\non tf-idf vectors")
# Out:
# clustering done in 0.66 ± 0.68 s
# Homogeneity: 0.336 ± 0.026
# Completeness: 0.400 ± 0.008
# V-measure: 0.365 ± 0.014
# Adjusted Rand-Index: 0.202 ± 0.012
# Silhouette Coefficient: 0.008 ± 0.002

# %%
kmeans = KMeans(
    n_clusters=true_k,
    max_iter=100,
    n_init=5,
)

fit_and_evaluate(kmeans, X_tfidf, name="KMeans\non tf-idf vectors")
# Out:
# clustering done in 0.63 ± 0.48 s
# Homogeneity: 0.336 ± 0.026
# Completeness: 0.400 ± 0.008
# V-measure: 0.365 ± 0.014
# Adjusted Rand-Index: 0.202 ± 0.012
# Silhouette Coefficient: 0.008 ± 0.001
