# %%
# !pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection # what is sklearn?

# %%
X, y = datasets.load_diabetes(return_X_y=True, as_frame=True) # returns tupple?

# %%
X
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
y
# Out:
# 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Name: target, Length: 442, dtype: float64

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 442 entries, 0 to 441
# Series name: target
# Non-Null Count  Dtype
# --------------  -----
# 442 non-null    float64
# dtypes: float64(1)
# memory usage: 3.6 KB

# %%
X, y = datasets.load_diabetes(return_X_y=True) 
# return tuple,

# %%
X
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
print(X.shape) # how many feautures and exmaples?
# Out:
# (442, 10)

# %%
X = X[:, np.newaxis, 2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-cf4e70aeddcb> in <cell line: 1>()
# ----> 1 X = X[:, np.newaxis, 2]
#
# IndexError: index 2 is out of bounds for axis 1 with size 1

# %%
X
# Out:
# array([[ 0.06169621],
#        [-0.05147406],
#        [ 0.04445121],
#        [-0.01159501],
#        [-0.03638469],
#        [-0.04069594],
#        [-0.04716281],
#        [-0.00189471],
#        [ 0.06169621],
#        [ 0.03906215],
#        [-0.08380842],
#        [ 0.01750591],
#        [-0.02884001],
#        [-0.00189471],
#        [-0.02560657],
#        [-0.01806189],
#        [ 0.04229559],
#        [ 0.01211685],
#        [-0.0105172 ],
#        [-0.01806189],
#        [-0.05686312],
#        [-0.02237314],
#        [-0.00405033],
#        [ 0.06061839],
#        [ 0.03582872],
#        [-0.01267283],
#        [-0.07734155],
#        [ 0.05954058],
#        [-0.02129532],
#        [-0.00620595],
#        [ 0.04445121],
#        [-0.06548562],
#        [ 0.12528712],
#        [-0.05039625],
#        [-0.06332999],
#        [-0.03099563],
#        [ 0.02289497],
#        [ 0.01103904],
#        [ 0.07139652],
#        [ 0.01427248],
#        [-0.00836158],
# ...

# %%
print(X[441])
# Out:
# [-0.0730303]

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.4)

# %%
X_train
# Out:
# array([[-0.03530688],
#        [ 0.03367309],
#        [-0.03099563],
#        [-0.01698407],
#        [-0.02237314],
#        [-0.03854032],
#        [ 0.01966154],
#        [ 0.00672779],
#        [-0.00512814],
#        [ 0.01858372],
#        [ 0.11127556],
#        [-0.00943939],
#        [-0.07410811],
#        [ 0.00996123],
#        [ 0.04552903],
#        [-0.02560657],
#        [ 0.02828403],
#        [ 0.06169621],
#        [-0.00512814],
#        [ 0.06169621],
#        [ 0.03259528],
#        [-0.00081689],
#        [-0.00728377],
#        [-0.03315126],
#        [ 0.11019775],
#        [-0.0374625 ],
#        [-0.02884001],
#        [ 0.09403057],
#        [-0.03854032],
#        [-0.06656343],
#        [-0.01590626],
#        [ 0.04768465],
#        [-0.06440781],
#        [-0.02452876],
#        [ 0.06169621],
#        [ 0.04445121],
#        [ 0.05630715],
#        [ 0.0347509 ],
#        [ 0.02181716],
#        [-0.05147406],
#        [-0.01159501],
# ...

# %%
X_test
# Out:
# array([[ 0.06492964],
#        [-0.02345095],
#        [-0.01806189],
#        [ 0.03906215],
#        [-0.00620595],
#        [ 0.03906215],
#        [-0.04931844],
#        [-0.00512814],
#        [-0.08380842],
#        [-0.05362969],
#        [-0.01482845],
#        [-0.08057499],
#        [ 0.02397278],
#        [ 0.12852056],
#        [-0.03961813],
#        [-0.03638469],
#        [-0.00836158],
#        [-0.03099563],
#        [ 0.04445121],
#        [ 0.00457217],
#        [-0.01590626],
#        [ 0.01103904],
#        [ 0.09295276],
#        [ 0.16085492],
#        [ 0.00564998],
#        [ 0.03798434],
#        [ 0.02073935],
#        [-0.046085  ],
#        [ 0.03043966],
#        [-0.02991782],
#        [ 0.00672779],
#        [ 0.03043966],
#        [-0.02345095],
#        [-0.07195249],
#        [ 0.00026092],
#        [-0.05686312],
#        [-0.06871905],
#        [ 0.01535029],
#        [-0.02021751],
#        [ 0.06708527],
#        [ 0.01858372],
# ...

# %%
y_train
# Out:
# array([101., 182., 274., 190., 257., 296., 214., 229.,  71.,  59., 103.,
#        281., 248.,  72.,  84.,  43.,  68., 151.,  77., 151., 132., 217.,
#         63., 262.,  90., 190., 332., 151., 252., 233., 178., 150., 183.,
#        179.,  78.,  47., 277., 113.,  96.,  93., 135., 150., 219., 166.,
#        131., 191., 242.,  44.,  80., 162., 275.,  53.,  88., 295., 288.,
#        104.,  94., 127.,  54.,  71., 317., 142., 220., 181., 245.,  48.,
#         64., 110.,  42., 302.,  61., 265.,  67., 200., 170., 259., 297.,
#        107.,  95., 225., 195., 185., 215.,  77., 163., 164., 264., 209.,
#        138., 172., 237., 109., 276.,  72., 182., 200., 180., 237.,  83.,
