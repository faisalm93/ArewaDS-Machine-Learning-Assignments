# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a random dataset
np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=1000)

# Create a histogram of the data
plt.hist(data, bins=20, color='blue', alpha=0.5)
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Distribution of Random Data')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset from github below
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# Print the first 5 rows of the DataFrame
print(df.head())

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset from github below
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# Create a histogram of the total bill amount
sns.histplot(data=df, x="total_bill", kde=True, color="blue", alpha=0.5)
# KDE means kernel density estimation 
plt.xlabel("Total Bill")
plt.ylabel("Frequency")
plt.title("Distribution of Total Bill Amounts")
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset from github below
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# Print the first 5 rows of the DataFrame
print(df.head())

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# Create a histogram of the tips amount
sns.histplot(data=df, x="tip", kde=True, color="green", alpha=0.5)
plt.xlabel("Tips Amount")
plt.ylabel("Frequency")
plt.title("Distribution of Tips Amounts")
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv")

# Print the first 5 rows of the DataFrame
print(df.head())

import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv")

# Create a histogram of diamond prices
plt.hist(df["price"], bins=30, color="purple", alpha=0.7)
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Distribution of Diamond Prices")
plt.show()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")
# Print the first 5 rows of the DataFrame
print(df.head())

# Create a histogram of the number of people in each group
sns.histplot(data=df, x="size", kde=True, color="orange", alpha=0.5)
plt.xlabel("Group Size")
plt.ylabel("Frequency")
plt.title("Distribution of Group Sizes")
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
